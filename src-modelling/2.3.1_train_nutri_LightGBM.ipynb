# %%
import pandas as pd
import numpy as np
import time
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm

from sklearn.preprocessing import MultiLabelBinarizer, LabelEncoder
from sklearn.model_selection import GridSearchCV, PredefinedSplit, ParameterGrid
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report
)

from lightgbm import LGBMClassifier

# %%
# 1. Load data
train = pd.read_csv("../gen/data_def_train_folds.csv")
test  = pd.read_csv("../gen/data_def_test.csv")

print("Train shape:", train.shape)
print("Test shape:", test.shape)
# Out:
# /var/folders/p2/b69xrmz146zc98k0yh6ylk1w0000gp/T/ipykernel_20735/1890095929.py:4: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   train = pd.read_csv("data_def_train_folds.csv")
# Train shape: (206068, 24)
# Test shape: (88315, 23)
# /var/folders/p2/b69xrmz146zc98k0yh6ylk1w0000gp/T/ipykernel_20735/1890095929.py:5: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   test  = pd.read_csv("data_def_test.csv")

# %%
# 2. Create combined column for Phase 2 (intrinsic + extrinsic)
train["labels_1_2_intr_extr"] = (
    train[["labels_1_intrinsic", "labels_2_extrinsic"]]
    .fillna("")
    .agg("|".join, axis=1)
    .str.strip("|")
)

test["labels_1_2_intr_extr"] = (
    test[["labels_1_intrinsic", "labels_2_extrinsic"]]
    .fillna("")
    .agg("|".join, axis=1)
    .str.strip("|")
)

# %%
train.head()
# Out:
#       barcode                    product_name nutriscore  nova_group  \
# 0   554004509         Pain de mie sans gluten          c           4
# 1  2000002466    2 MINI BAGUETTES SANS GLUTEN          c           4
# 2  2000003197  Véritable Andouille de Guémené          e           4
# 3  2000010775            Escalope soja et blé          b           3
# 4  8112100281                 Pure Sesame Oil          c           2
#
#       mapped_category                                      labels_string  \
# 0           3.1 Bread                         NO_GLUTEN|NO_PRESERVATIVES
# 1           3.1 Bread  CROSSED_GRAIN|CROSSED_GRAIN_DZG|EU_ORGANIC_LOG...
# 2  5.1 Processed meat                                  SMOKED_BEECH_WOOD
# 3            5.4 Meat                          EVU_VEGETARIAN|VEGETARIAN
# 4     6.1 Fats & oils                                            NON_GMO
#
#    n_labels_total          labels_1_intrinsic  n_1_intrinsic  \
# 0               2  NO_GLUTEN|NO_PRESERVATIVES              2
# 1               5                   NO_GLUTEN              1
# 2               1           SMOKED_BEECH_WOOD              1
# 3               2                         NaN              0
# 4               1                         NaN              0
#
#                                   labels_2_extrinsic  ...  n_additives  \
# 0                                                NaN  ...          2.0
# 1  CROSSED_GRAIN|CROSSED_GRAIN_DZG|EU_ORGANIC_LOG...  ...          2.0
# 2                                                NaN  ...          2.0
# 3                          EVU_VEGETARIAN|VEGETARIAN  ...          0.0
# 4                                            NON_GMO  ...          0.0
#
#   n_ingredients   main_mapped_category label_tier               stratify_raw  \
# 0          22.0  3. Cereals & Starches          1  3. Cereals & Starches | 4
# 1          15.0  3. Cereals & Starches          2  3. Cereals & Starches | 4
# 2          10.0   5. Meat, Fish & Eggs          1   5. Meat, Fish & Eggs | 4
# 3          32.0   5. Meat, Fish & Eggs          1   5. Meat, Fish & Eggs | 3
# 4           1.0       6. Fats & Sauces          1       6. Fats & Sauces | 2
#
#                     stratify  split nova_group_fold  nutriscore_fold  \
# 0  3. Cereals & Starches | 4  train               4                3
# 1  3. Cereals & Starches | 4  train               4                3
# 2   5. Meat, Fish & Eggs | 4  train               1                1
# 3   5. Meat, Fish & Eggs | 3  train               1                3
# 4       6. Fats & Sauces | 2  train               4                4
#
#                                 labels_1_2_intr_extr
# 0                         NO_GLUTEN|NO_PRESERVATIVES
# 1  NO_GLUTEN|CROSSED_GRAIN|CROSSED_GRAIN_DZG|EU_O...
# 2                                  SMOKED_BEECH_WOOD
# 3                          EVU_VEGETARIAN|VEGETARIAN
# 4                                            NON_GMO
#
# [5 rows x 25 columns]

# %%
test.head()
# Out:
#       barcode                                    product_name nutriscore  \
# 0   790200123        Fine Chocolate Candy Bar, Dark Chocolate          c
# 1  2000001780                                Pizza Margherita          c
# 2  3004032145                        Chinois Nature Décongelé          e
# 3  8005158306  Nuovo Pasta, Organic Ravioli, Butternut Squash          a
# 4  8295663177                      Balsamic Vinegar Of Modena          c
#
#    nova_group             mapped_category    labels_string  n_labels_total  \
# 0           4      9.3 Chocolate products        NO_GLUTEN               1
# 1           3  7.2 Pizza, pies and quiche  EU_ORGANIC_LOGO               1
# 2           4                9.2 Pastries         UNFROZEN               1
# 3           4                2.5 Potatoes  EU_ORGANIC_LOGO               1
# 4           4    6.2 Dressings and sauces          NON_GMO               1
#
#   labels_1_intrinsic  n_1_intrinsic labels_2_extrinsic  ...  \
# 0          NO_GLUTEN              1                NaN  ...
# 1                NaN              0    EU_ORGANIC_LOGO  ...
# 2           UNFROZEN              1                NaN  ...
# 3                NaN              0    EU_ORGANIC_LOGO  ...
# 4                NaN              0            NON_GMO  ...
#
#              countries n_additives  n_ingredients  \
# 0        united-states         2.0            8.0
# 1               france         0.0           35.0
# 2               france        11.0           48.0
# 3        united-states         1.0           33.0
# 4  united-states|world         0.0            3.0
#
#             main_mapped_category label_tier  \
# 0   9. Sweet Products & Desserts          1
# 1  7. Composite & Prepared Meals          1
# 2   9. Sweet Products & Desserts          1
# 3         2. Fruits & Vegetables          1
# 4               6. Fats & Sauces          1
#
#                         stratify_raw                           stratify split  \
# 0   9. Sweet Products & Desserts | 4   9. Sweet Products & Desserts | 4  test
# 1  7. Composite & Prepared Meals | 3  7. Composite & Prepared Meals | 3  test
# 2   9. Sweet Products & Desserts | 4   9. Sweet Products & Desserts | 4  test
# 3         2. Fruits & Vegetables | 4         2. Fruits & Vegetables | 4  test
# 4               6. Fats & Sauces | 4               6. Fats & Sauces | 4  test
#
#    core_slice labels_1_2_intr_extr
# 0       False            NO_GLUTEN
# 1       False      EU_ORGANIC_LOGO
# 2       False             UNFROZEN
# 3       False      EU_ORGANIC_LOGO
# 4       False              NON_GMO
#
# [5 rows x 24 columns]

# %%
# 3. Target + folds
target = "nutriscore" 
fold_col = f"{target}_fold"

# Encode target variable
le = LabelEncoder()
y_train = le.fit_transform(train[target])
y_test = le.transform(test[target])

print("Class mapping:", dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# Class mapping: {'a': 0, 'b': 1, 'c': 2, 'd': 3, 'e': 4}

# %%
# 4. Define phases (name -> column)
phases = {
    "phase1_intrinsic": "labels_1_intrinsic",
    "phase2_intr+extr": "labels_1_2_intr_extr",
    "phase3_all_labels": "labels_string",
}

# %%
# 5. Define LightGBM hyperparameter grid
lgb_param_grid = {
    "n_estimators": [50, 100, 300],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 5],
    "num_leaves": [10, 30, 50]
}

all_phase_results = []
all_best_params = []

# %%
# 6. Loop over phases
for phase_name, label_col in phases.items():
    print("\n" + "="*90)
    print(f"=== {phase_name} – Using column '{label_col}' ===")
    print("="*90)

    # 6.1 Encode label features
    train[label_col] = train[label_col].fillna("")
    test[label_col]  = test[label_col].fillna("")

    train_labels = train[label_col].apply(lambda x: x.split("|") if x != "" else [])
    test_labels  = test[label_col].apply(lambda x: x.split("|") if x != "" else [])

    mlb = MultiLabelBinarizer(sparse_output=True)
    X_train_labels = mlb.fit_transform(train_labels)
    X_test_labels  = mlb.transform(test_labels)

    X_train_labels = X_train_labels.astype(np.float32)
    X_test_labels  = X_test_labels.astype(np.float32)

    print(f"Encoded label matrix shape (train): {X_train_labels.shape}")
    print(f"Encoded label matrix shape (test):  {X_test_labels.shape}")

    # 6.2 Hyperparameter tuning with predefined folds
    print("\n>>> Hyperparameter search using predefined 5-fold CV")

    fold_ids = train[fold_col].values
    test_fold = fold_ids - 1   # convert 1–5 > 0–4
    ps = PredefinedSplit(test_fold=test_fold)

    base_lgb = LGBMClassifier(
        objective="multiclass",
        random_state=42,
        n_jobs=-1,
        verbosity=-1,
        force_row_wise=True
    )

    grid = GridSearchCV(
        estimator=base_lgb,
        param_grid=lgb_param_grid,
        cv=ps,
        scoring="balanced_accuracy",
        n_jobs=-1,
        verbose=1,
        return_train_score=True
    )

    grid_start = time.perf_counter()
    grid.fit(X_train_labels, y_train)
    grid_end = time.perf_counter()
    grid_time = grid_end - grid_start

    best_params = grid.best_params_
    best_score = grid.best_score_

    print(f"\nBest parameters for {phase_name}:")
    for k, v in best_params.items():
        print(f"  {k}: {v}")
    print(f"Best 5-fold balanced accuracy (train CV): {best_score:.4f}")
    print(f"Hyperparameter search time: {grid_time:.2f} s")

    all_best_params.append({
        "Phase": phase_name,
        **best_params,
        "CV_BalAcc": best_score,
        "Hyperparam Time (s)": grid_time
    })

    # 6.3 Train final model on full training data, evaluate on test
    print("\n>>> Final model training on full training data & test evaluation")

    lgb_final = LGBMClassifier(
        objective="multiclass",
        random_state=42,
        n_jobs=-1,
        verbosity=-1,           
        force_row_wise=True,    
        **best_params
    )

    train_start = time.perf_counter()
    lgb_final.fit(X_train_labels, y_train)
    train_end = time.perf_counter()
    train_time = train_end - train_start

    pred_start = time.perf_counter()
    y_pred_test = lgb_final.predict(X_test_labels)
    pred_end = time.perf_counter()
    pred_time = pred_end - pred_start

    # Metrics
    acc_test = accuracy_score(y_test, y_pred_test)
    bal_acc_test = balanced_accuracy_score(y_test, y_pred_test)
    precision_macro = precision_score(y_test, y_pred_test, average='macro', zero_division=0)
    recall_macro = recall_score(y_test, y_pred_test, average='macro', zero_division=0)
    f1_macro = f1_score(y_test, y_pred_test, average='macro', zero_division=0)
    f1_micro = f1_score(y_test, y_pred_test, average='micro', zero_division=0)

    print(f"\n=== Test Performance – {phase_name} (Nutri-Score) ===")
    print(f"Accuracy:           {acc_test:.4f}")
    print(f"Balanced Accuracy:  {bal_acc_test:.4f}")
    print(f"Precision (Macro):  {precision_macro:.4f}")
    print(f"Recall (Macro):     {recall_macro:.4f}")
    print(f"F1 (Macro):         {f1_macro:.4f}")
    print(f"F1 (Micro):         {f1_micro:.4f}")
    print(f"Train time (full train):   {train_time:.2f} s")
    print(f"Predict time (test set):   {pred_time:.2f} s")

    class_names = [str(c) for c in le.classes_]
    print("\nDetailed Classification Report:")
    print(classification_report(y_test, y_pred_test, target_names=class_names, zero_division=0))

    # Confusion Matrix
    cm = confusion_matrix(y_test, y_pred_test)
    plt.figure(figsize=(6,5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(f"Confusion Matrix – {phase_name} – LightGBM (Nutri-Score)")
    plt.tight_layout()
    plt.show()

    # Store results
    all_phase_results.append({
        "Phase": phase_name,
        "CV_BalAcc": best_score,
        "Test_Accuracy": acc_test,
        "Test_BalAccuracy": bal_acc_test,
        "Precision (Macro)": precision_macro,
        "Recall (Macro)": recall_macro,
        "F1 (Macro)": f1_macro,
        "F1 (Micro)": f1_micro,
        "Train Time (s)": train_time,
        "Predict Time (s)": pred_time,
        "Hyperparam Time (s)": grid_time
    })
# Out:
# ==========================================================================================
# === phase1_intrinsic – Using column 'labels_1_intrinsic' ===
# ==========================================================================================
# Encoded label matrix shape (train): (206068, 359)
# Encoded label matrix shape (test):  (88315, 359)
#
# >>> Hyperparameter search using predefined 5-fold CV
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['ARTIFICIAL_FLAVOR', 'ENRICHED_WITH_OMEGA3', 'HIGH_IN_CARBOHYDRATES', 'HIGH_IN_OMEGA3_AND_OMEGA6', 'HIGH_IN_PROTEIN_AND_FIBRE', 'HIGH_IN_VITAMIN_K', 'KETOGENIC', 'LOW_FODMAP', 'MINIMALLY_PROCESSED', 'NATURAL_SUGARS_FROM_OATS', 'NATURAL_SUGARS_UNALTERED', 'NOT_FROZEN', 'NO_ADDED_ARTIFICIAL_SWEETENERS', 'NO_ADDITIVES_PRESERVATIVES_COLORANTS', 'NO_ANHYDRIDES', 'NO_AROMA_COLORANT_PRESERVATIVE', 'NO_ARTIFICIAL_DYES', 'NO_ARTIFICIAL_E_NUMBERS', 'NO_ARTIFICIAL_PRESERVATIVES_FLAVOURS_DYES', 'NO_CARRAGEENAN', 'NO_CHEMICAL_INGREDIENTS', 'NO_CHEMICAL_TREATMENT', 'NO_CLEANING_AGENTS', 'NO_COLORANT_AROMA_PRESERVATIVE', 'NO_DYES_PRESERVATIVES_HYDROGENATED_FATS', 'NO_EXTRACTS', 'NO_FRUIT', 'NO_GARLIC_ONION', 'NO_GLUTEN_COLORANT_PRESERVATIVE', 'NO_HIGH_PRESSURE_PROCESSING', 'NO_HONEY', 'NO_LARD', 'NO_METAL_MOLD', 'NO_NUT_TRACES', 'NO_PALM_OIL_DERIVATIVES', 'NO_PHOSPHORIC_ACID', 'NO_POTATO_FLAKES', 'NO_PRESERVATIVES_MSG', 'NO_PRESERVATIVE_ARTIFICIAL_COLORANT', 'NO_SOURDOUGH', 'NO_STEROIDS', 'NO_TAURINE', 'RICH_IN_WHOLE_GRAINS', 'SOURCE_OF_POTASSIUM'] will be ignored
#   warnings.warn(
# Best parameters for phase1_intrinsic:
#   learning_rate: 0.1
#   max_depth: 5
#   n_estimators: 300
#   num_leaves: 30
# Best 5-fold balanced accuracy (train CV): 0.2543
# Hyperparameter search time: 1295.05 s
#
# >>> Final model training on full training data & test evaluation
#
# === Test Performance – phase1_intrinsic (Nutri-Score) ===
# Accuracy:           0.3017
# Balanced Accuracy:  0.2549
# Precision (Macro):  0.3520
# Recall (Macro):     0.2549
# F1 (Macro):         0.2052
# F1 (Micro):         0.3017
# Train time (full train):   3.74 s
# Predict time (test set):   2.85 s
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            a       0.41      0.13      0.20     14047
#            b       0.35      0.02      0.04     11057
#            c       0.35      0.16      0.22     20236
#            d       0.37      0.09      0.14     20659
#            e       0.28      0.88      0.43     22316
#
#     accuracy                           0.30     88315
#    macro avg       0.35      0.25      0.21     88315
# weighted avg       0.35      0.30      0.23     88315
# ==========================================================================================
# === phase2_intr+extr – Using column 'labels_1_2_intr_extr' ===
# ==========================================================================================
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['ARTIFICIAL_FLAVOR', 'CERT_BIODYNAMIC', 'COASTAL_FISHING', 'DLG_BRONZE_MEDAL', 'ENRICHED_WITH_OMEGA3', 'EU_ORGANIC_CERT_FB', 'EU_ORGANIC_CERT_MY', 'GLUTEN_FREE_VEGAN', 'GLUTEN_LACTOSE_SULFITE_FREE', 'HAZELNUT_FREE', 'HIGH_IN_CARBOHYDRATES', 'HIGH_IN_OMEGA3_AND_OMEGA6', 'HIGH_IN_PROTEIN_AND_FIBRE', 'HIGH_IN_VITAMIN_K', 'INVALID_OR_ERROR', 'ISO_50001', 'KETOGENIC', 'LACTOSE_DAIRY_FREE', 'LOW_FODMAP', 'MAY_CONTAIN_SULPHITES', 'MILK_DERIVATIVE_FREE', 'MINIMALLY_PROCESSED', 'NATURAL_SUGARS_FROM_OATS', 'NATURAL_SUGARS_UNALTERED', 'NOT_FROZEN', 'NO_ADDED_ARTIFICIAL_SWEETENERS', 'NO_ADDITIVES_PRESERVATIVES_COLORANTS', 'NO_ANHYDRIDES', 'NO_ANIMAL_INGREDIENTS', 'NO_AROMA_COLORANT_PRESERVATIVE', 'NO_ARTIFICIAL_DYES', 'NO_ARTIFICIAL_E_NUMBERS', 'NO_ARTIFICIAL_PRESERVATIVES_FLAVOURS_DYES', 'NO_CARRAGEENAN', 'NO_CHEMICAL_INGREDIENTS', 'NO_CHEMICAL_TREATMENT', 'NO_CLEANING_AGENTS', 'NO_COLORANT_AROMA_PRESERVATIVE', 'NO_DYES_PRESERVATIVES_HYDROGENATED_FATS', 'NO_EXTRACTS', 'NO_FRUIT', 'NO_GARLIC_ONION', 'NO_GLUTEN_COLORANT_PRESERVATIVE', 'NO_HIGH_PRESSURE_PROCESSING', 'NO_HONEY', 'NO_LARD', 'NO_METAL_MOLD', 'NO_MILK_EGGS', 'NO_MINERAL_NITROGEN_FERTILIZER', 'NO_NUT_TRACES', 'NO_PALM_OIL_DERIVATIVES', 'NO_PHOSPHORIC_ACID', 'NO_POTATO_FLAKES', 'NO_PRESERVATIVES_MSG', 'NO_PRESERVATIVE_ARTIFICIAL_COLORANT', 'NO_PREVENTIVE_ANTIBIOTICS', 'NO_SOURDOUGH', 'NO_STEROIDS', 'NO_TAURINE', 'RICH_IN_WHOLE_GRAINS', 'SOURCE_OF_POTASSIUM', 'WARNING_HIGH_SATURATED_FAT_SODIUM', 'WARNING_INFANTS_UNDER_12M', 'WARNING_NURSING_WOMEN'] will be ignored
#   warnings.warn(
# Encoded label matrix shape (train): (206068, 808)
# Encoded label matrix shape (test):  (88315, 808)
#
# >>> Hyperparameter search using predefined 5-fold CV
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best parameters for phase2_intr+extr:
#   learning_rate: 0.1
#   max_depth: 5
#   n_estimators: 300
#   num_leaves: 30
# Best 5-fold balanced accuracy (train CV): 0.3457
# Hyperparameter search time: 1349.56 s
#
# >>> Final model training on full training data & test evaluation
#
# === Test Performance – phase2_intr+extr (Nutri-Score) ===
# Accuracy:           0.3758
# Balanced Accuracy:  0.3463
# Precision (Macro):  0.3783
# Recall (Macro):     0.3463
# F1 (Macro):         0.3173
# F1 (Micro):         0.3758
# Train time (full train):   4.71 s
# Predict time (test set):   3.51 s
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            a       0.35      0.47      0.40     14047
#            b       0.40      0.04      0.07     11057
#            c       0.35      0.37      0.36     20236
#            d       0.40      0.19      0.26     20659
#            e       0.40      0.66      0.50     22316
#
#     accuracy                           0.38     88315
#    macro avg       0.38      0.35      0.32     88315
# weighted avg       0.38      0.38      0.34     88315
# ==========================================================================================
# === phase3_all_labels – Using column 'labels_string' ===
# ==========================================================================================
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/preprocessing/_label.py:900: UserWarning: unknown class(es) ['ARTIFICIAL_FLAVOR', 'CARREFOUR_CLASSIC', 'CERT_BIODYNAMIC', 'COASTAL_FISHING', 'DLG_BRONZE_MEDAL', 'ENRICHED_WITH_OMEGA3', 'EU_ORGANIC_CERT_FB', 'EU_ORGANIC_CERT_MY', 'GLUTEN_FREE_VEGAN', 'GLUTEN_LACTOSE_SULFITE_FREE', 'GOLD_MEDAL_GENERIC', 'GOLD_MEDAL_MILK_GRADE_A', 'HAZELNUT_FREE', 'HIGH_IN_CARBOHYDRATES', 'HIGH_IN_OMEGA3_AND_OMEGA6', 'HIGH_IN_PROTEIN_AND_FIBRE', 'HIGH_IN_VITAMIN_K', 'INVALID_OR_ERROR', 'ISO_50001', 'KETOGENIC', 'LACTOSE_DAIRY_FREE', 'LOW_FODMAP', 'MAY_CONTAIN_SULPHITES', 'MILK_DERIVATIVE_FREE', 'MINIMALLY_PROCESSED', 'NATURAL_SUGARS_FROM_OATS', 'NATURAL_SUGARS_UNALTERED', 'NOT_FROZEN', 'NO_ADDED_ARTIFICIAL_SWEETENERS', 'NO_ADDITIVES_PRESERVATIVES_COLORANTS', 'NO_ANHYDRIDES', 'NO_ANIMAL_INGREDIENTS', 'NO_AROMA_COLORANT_PRESERVATIVE', 'NO_ARTIFICIAL_DYES', 'NO_ARTIFICIAL_E_NUMBERS', 'NO_ARTIFICIAL_PRESERVATIVES_FLAVOURS_DYES', 'NO_CARRAGEENAN', 'NO_CHEMICAL_INGREDIENTS', 'NO_CHEMICAL_TREATMENT', 'NO_CLEANING_AGENTS', 'NO_COLORANT_AROMA_PRESERVATIVE', 'NO_DYES_PRESERVATIVES_HYDROGENATED_FATS', 'NO_EXTRACTS', 'NO_FRUIT', 'NO_GARLIC_ONION', 'NO_GLUTEN_COLORANT_PRESERVATIVE', 'NO_HIGH_PRESSURE_PROCESSING', 'NO_HONEY', 'NO_LARD', 'NO_METAL_MOLD', 'NO_MILK_EGGS', 'NO_MINERAL_NITROGEN_FERTILIZER', 'NO_NUT_TRACES', 'NO_PALM_OIL_DERIVATIVES', 'NO_PHOSPHORIC_ACID', 'NO_POTATO_FLAKES', 'NO_PRESERVATIVES_MSG', 'NO_PRESERVATIVE_ARTIFICIAL_COLORANT', 'NO_PREVENTIVE_ANTIBIOTICS', 'NO_SOURDOUGH', 'NO_STEROIDS', 'NO_TAURINE', 'RICH_IN_WHOLE_GRAINS', 'SAVEURS_D_AILLEURS', 'SAVEUR_INTENSE', 'SAVEUR_JAMBON', 'SOURCE_OF_POTASSIUM', 'WARNING_HIGH_SATURATED_FAT_SODIUM', 'WARNING_INFANTS_UNDER_12M', 'WARNING_NURSING_WOMEN'] will be ignored
#   warnings.warn(
# Encoded label matrix shape (train): (206068, 870)
# Encoded label matrix shape (test):  (88315, 870)
#
# >>> Hyperparameter search using predefined 5-fold CV
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
#
# Best parameters for phase3_all_labels:
#   learning_rate: 0.1
#   max_depth: 5
#   n_estimators: 300
#   num_leaves: 50
# Best 5-fold balanced accuracy (train CV): 0.3518
# Hyperparameter search time: 1458.90 s
#
# >>> Final model training on full training data & test evaluation
#
# === Test Performance – phase3_all_labels (Nutri-Score) ===
# Accuracy:           0.3796
# Balanced Accuracy:  0.3518
# Precision (Macro):  0.3842
# Recall (Macro):     0.3518
# F1 (Macro):         0.3255
# F1 (Micro):         0.3796
# Train time (full train):   4.86 s
# Predict time (test set):   3.16 s
#
# Detailed Classification Report:
#               precision    recall  f1-score   support
#
#            a       0.35      0.49      0.41     14047
#            b       0.42      0.05      0.09     11057
#            c       0.35      0.37      0.36     20236
#            d       0.39      0.21      0.27     20659
#            e       0.41      0.64      0.50     22316
#
#     accuracy                           0.38     88315
#    macro avg       0.38      0.35      0.33     88315
# weighted avg       0.38      0.38      0.35     88315

# %%
# 7. Summary tables
results_df = pd.DataFrame(all_phase_results)
best_params_df = pd.DataFrame(all_best_params)

print("\n=== Summary – Test Performance per Phase (LightGBM, Nutri-Score) ===")
print(results_df)

print("\n=== Best Hyperparameters per Phase ===")
print(best_params_df)

# Save results
results_df.to_csv("../results/lgb_nutriscore_test_results.csv", index=False)
best_params_df.to_csv("../results/lgb_nutriscore_best_params.csv", index=False)
# Out:
# === Summary – Test Performance per Phase (LightGBM, Nutri-Score) ===
#                Phase  CV_BalAcc  Test_Accuracy  Test_BalAccuracy  \
# 0   phase1_intrinsic   0.254326       0.301670          0.254863
# 1   phase2_intr+extr   0.345669       0.375825          0.346281
# 2  phase3_all_labels   0.351831       0.379641          0.351771
#
#    Precision (Macro)  Recall (Macro)  F1 (Macro)  F1 (Micro)  Train Time (s)  \
# 0           0.352025        0.254863    0.205151    0.301670        3.742487
# 1           0.378306        0.346281    0.317283    0.375825        4.708749
# 2           0.384196        0.351771    0.325484    0.379641        4.858988
#
#    Predict Time (s)  Hyperparam Time (s)
# 0          2.849460          1295.054848
# 1          3.506261          1349.555372
# 2          3.156684          1458.903676
#
# === Best Hyperparameters per Phase ===
#                Phase  learning_rate  max_depth  n_estimators  num_leaves  \
# 0   phase1_intrinsic            0.1          5           300          30
# 1   phase2_intr+extr            0.1          5           300          30
# 2  phase3_all_labels            0.1          5           300          50
#
#    CV_BalAcc  Hyperparam Time (s)
# 0   0.254326          1295.054848
# 1   0.345669          1349.555372
# 2   0.351831          1458.903676
