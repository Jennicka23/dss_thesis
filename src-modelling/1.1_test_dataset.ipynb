# %% [markdown]
# # Test dataset
# Add core_slice flag to test dataset

# %%
import pandas as pd

# %%
df_test  = pd.read_csv("../gen/data_def_test.csv")

# Define core slice
df_test["core_slice"] = (
    (df_test["n_1_intrinsic"] > 0) &
    (df_test["n_2_extrinsic"] > 0) &
    (df_test["n_3_packaging"] > 0)
)

# Check proportions
core_share = df_test["core_slice"].mean() * 100
core_n = df_test["core_slice"].sum()
print(f"Core slice size: {core_n:,} items ({core_share:.2f}% of test set)")

# save for reference
df_test.to_csv("../gen/data_def_test.csv", index=False)
print("Updated data_def_test.csv with 'core_slice' flag.")
# Out:
# C:\Users\Voorro\AppData\Local\Temp\ipykernel_6116\1665846115.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_test  = pd.read_csv("../gen/data_def_test.csv")
# Core slice size: 4,876 items (5.52% of test set)
# Updated data_def_test.csv with 'core_slice' flag.

# %%
df_test.head()
# Out:
#       barcode                                    product_name nutriscore  \
# 0   790200123        Fine Chocolate Candy Bar, Dark Chocolate          c
# 1  2000001780                                Pizza Margherita          c
# 2  3004032145                        Chinois Nature Décongelé          e
# 3  8005158306  Nuovo Pasta, Organic Ravioli, Butternut Squash          a
# 4  8295663177                      Balsamic Vinegar Of Modena          c
#
#    nova_group             mapped_category    labels_string  n_labels_total  \
# 0           4      9.3 Chocolate products        NO_GLUTEN               1
# 1           3  7.2 Pizza, pies and quiche  EU_ORGANIC_LOGO               1
# 2           4                9.2 Pastries         UNFROZEN               1
# 3           4                2.5 Potatoes  EU_ORGANIC_LOGO               1
# 4           4    6.2 Dressings and sauces          NON_GMO               1
#
#   labels_1_intrinsic  n_1_intrinsic labels_2_extrinsic  ...  \
# 0          NO_GLUTEN              1                NaN  ...
# 1                NaN              0    EU_ORGANIC_LOGO  ...
# 2           UNFROZEN              1                NaN  ...
# 3                NaN              0    EU_ORGANIC_LOGO  ...
# 4                NaN              0            NON_GMO  ...
#
#                                     brands            countries  n_additives  \
# 0      Simply,  Simply Natural Foods  Llc.        united-states          2.0
# 1                             ALICE Et BIO               france          0.0
# 2                              Intermarché               france         11.0
# 3              Nuovo Pasta Productions Ltd        united-states          1.0
# 4  Acetificio Marcello Denigris, De Nigris  united-states|world          0.0
#
#   n_ingredients           main_mapped_category  label_tier  \
# 0           8.0   9. Sweet Products & Desserts           1
# 1          35.0  7. Composite & Prepared Meals           1
# 2          48.0   9. Sweet Products & Desserts           1
# 3          33.0         2. Fruits & Vegetables           1
# 4           3.0               6. Fats & Sauces           1
#
#                         stratify_raw                           stratify  \
# 0   9. Sweet Products & Desserts | 4   9. Sweet Products & Desserts | 4
# 1  7. Composite & Prepared Meals | 3  7. Composite & Prepared Meals | 3
# 2   9. Sweet Products & Desserts | 4   9. Sweet Products & Desserts | 4
# 3         2. Fruits & Vegetables | 4         2. Fruits & Vegetables | 4
# 4               6. Fats & Sauces | 4               6. Fats & Sauces | 4
#
#    split core_slice
# 0   test      False
# 1   test      False
# 2   test      False
# 3   test      False
# 4   test      False
#
# [5 rows x 23 columns]
